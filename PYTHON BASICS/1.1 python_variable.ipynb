# %% [markdown]
# ## Variables
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.
#
# **Outline:**
#
# 1. Introduction to Variables
# 2. Declaring and Assigning Variables
# 3. Naming Conventions
# 4. Understanding Variable Types
# 5. Type Checking and Conversion
# 6. Dynamic Typing
# 7. Practical Examples and Common Errors

# %%
## Declaring And Assigning Variables

age=21
height=5.11
name="Ujjaval"
is_student=True

## printing the variables

print("age :",age)
print("Height:",height)
print("Name:",name)
# Out:
# age : 21
# Height: 5.11
# Name: Ujjaval

# %% [markdown]
# ## 📝 Naming Conventions
#
# - Variable names should be **descriptive** and meaningful.
# - They must start with a **letter** or an **underscore (`_`)**.
# - They can contain **letters, numbers, and underscores**.
# - Variable names are **case-sensitive** (`Age` and `age` are different).

# %%
#valid variable names

first_name="KRish"
last_name="Naik"

# %% [markdown]
# ## 🚫 Invalid Variable Names
#
# - `2age = 30`
#   ❌ Cannot start with a number.
#
# - `first-name = "Krish"`
#   ❌ Hyphens are not allowed (they are interpreted as subtraction).
#
# - `@name = "Krish"`
#   ❌ Special characters like `@` are not permitted.

# %%
## case sensitivity
name="Krish"
Name="Naik"

# %%
name==Name
# Out:
# False

# %% [markdown]
# ## 🔍 Understanding Variable Types
#
# Python is **dynamically typed**, meaning the type of a variable is determined at runtime.

# %%
### Examples:

age = 25          # int
height = 6.1      # float
name = "Krish"    # str
is_student = True # bool

print(type(name)) # <class 'str'>
# Out:
# <class 'str'>

# %%
type(age)
# Out:
# int

# %%
#type conversion

age=25
age_str=str(age)

print(type(age))
print(type(age_str))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %% [markdown]
# ### Value Error
# A **ValueError** in type conversion happens in Python when you try to convert a value into another type, but the value isn’t valid for that conversion.

# %%
name="Krish"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 name="Krish"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Krish'

# %%
height=5.11
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 5

# %%
float(int(height))
# Out:
# 5.0

# %% [markdown]
# ### Dynamic Typing
# - Python allows the type of a vraible to change as the program executes.

# %%
var=10 #int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input

age=int(input("What is the age"))
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
#Simple Calculator

Num1=int(input("Enter first number :"))
Num2=int(input('Enter Second number :'))

Add_result=Num1+Num2
Sub=Num1-Num2
multi=Num2*Num1
divide=Num1/Num2

print('Sum ',Add_result)
print('Substraction ',Sub)
print("Multiplication ",multi)
print('devision ', divide)
# Out:
# Sum  20
# Substraction  10
# Multiplication  75
# devision  3.0
