# %% [markdown]
# ## Syntax and Semantics in Python
#
# ### Outline
# 1. Single-line Comments and Multiline Comments
# 2. Definition of Syntax and Semantics
# 3. Basic Syntax Rules in Python
# 4. Understanding Semantics in Python
# 5. Common Syntax Errors and How to Avoid Them
# 6. Practical Code Examples
#
# ---
#
# ### 📝 Syntax
# - Refers to the **set of rules** that defines the combinations of symbols considered correctly structured programs in a language.
# - In simpler terms, syntax is about the **correct arrangement of words and symbols** in code.
#
# ---
#
# ### 💡 Semantics
# - Refers to the **meaning or interpretation** of the symbols, characters, and commands in a language.
# - It is about **what the code is supposed to do** when it runs.

# %%
## Basic Syntax Rules In Python
## Case sensitivity- Python is case sensitive

name="Ujjaval"
Name="Dhakad"

print(name)
print(Name)
# Out:
# Ujjaval
# Dhakad

# %% [markdown]
# ## Indentation
# Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

age=32
if age>30:
    
    print(age)
    
print(age)
# Out:
# 32
# 32

# %%
## This is a single line comment
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation
##Use a backslash (\) to continue a statement to the next line

total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple Statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Understand  Semnatics In Python
# variable assignment
age=32 ##age is an integer
name="ujjaval" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %% [markdown]
# ## Type inference
# Type inference is the process by which a programming language automatically determines the type of a variable or expression without you explicitly declaring it.

# %%
## Type Inference

variable=10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### Name error
# A NameError in Python happens when you try to use a variable, function, or object that hasn’t been defined yet (or is out of scope). In other words, Python doesn’t recognize the name you’re referring to.

# %%
## Name Error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 ## Name Error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code exmaples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
